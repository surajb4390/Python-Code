# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv')
df
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %% [markdown]
# # How to know columns

# %%
df.columns
# Out:
# Index(['sr', 'name', 'study', 'marks', 'city', 'pincode'], dtype='object')

# %% [markdown]
# # How to read any row

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',nrows = 2)
df
# Out:
#    sr    name  study  marks    city  pincode
# 0   1   suraj      3     56  satara   412547
# 1   2  sammed      5     67    pune   423876

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',nrows = 1)
df
# Out:
#    sr   name  study  marks    city  pincode
# 0   1  suraj      3     56  satara   412547

# %% [markdown]
# # How to read columns

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',usecols = [1])
df
# Out:
#      name
# 0   suraj
# 1  sammed
# 2  nilesh
# 3  ritesh

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',usecols = [0,1,2])

# %%
df
# Out:
#    sr    name  study
# 0   1   suraj      3
# 1   2  sammed      5
# 2   3  nilesh      6
# 3   4  ritesh      4

# %% [markdown]
# # How to skip any row

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',skiprows = 1) #skip no of rows from top here 1 row skip
df
# Out:
#    1   suraj  3  56    satara  412547
# 0  2  sammed  5  67      pune  423876
# 1  3  nilesh  6  72  banglore  454231
# 2  4  ritesh  4  63    mumbai  414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',skiprows = [1])
df
# Out:
#    sr    name  study  marks      city  pincode
# 0   2  sammed      5     67      pune   423876
# 1   3  nilesh      6     72  banglore   454231
# 2   4  ritesh      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',skiprows = [1,2])
df
# Out:
#    sr    name  study  marks      city  pincode
# 0   3  nilesh      6     72  banglore   454231
# 1   4  ritesh      4     63    mumbai   414098

# %% [markdown]
# # How to convert any colunm as index

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',index_col = 'sr')
df
# Out:
#       name  study  marks      city  pincode
# sr
# 1    suraj      3     56    satara   412547
# 2   sammed      5     67      pune   423876
# 3   nilesh      6     72  banglore   454231
# 4   ritesh      4     63    mumbai   414098

# %% [markdown]
# # OR

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',index_col = 0)  #here 0 = index
df
# Out:
#       name  study  marks      city  pincode
# sr
# 1    suraj      3     56    satara   412547
# 2   sammed      5     67      pune   423876
# 3   nilesh      6     72  banglore   454231
# 4   ritesh      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',skipfooter = 1)
df
# Out:
# <ipython-input-14-669b809d9ca3>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',skipfooter = 1)
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',header = 1)
df
# Out:
#    1   suraj  3  56    satara  412547
# 0  2  sammed  5  67      pune  423876
# 1  3  nilesh  6  72  banglore  454231
# 2  4  ritesh  4  63    mumbai  414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',header = None)
df
# Out:
#     0       1      2      3         4        5
# 0  sr    name  study  marks      city  pincode
# 1   1   suraj      3     56    satara   412547
# 2   2  sammed      5     67      pune   423876
# 3   3  nilesh      6     72  banglore   454231
# 4   4  ritesh      4     63    mumbai   414098

# %%
 df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',header = None,prefix = 'col')
 df
# Out:
#   col0    col1   col2   col3      col4     col5
# 0   sr    name  study  marks      city  pincode
# 1    1   suraj      3     56    satara   412547
# 2    2  sammed      5     67      pune   423876
# 3    3  nilesh      6     72  banglore   454231
# 4    4  ritesh      4     63    mumbai   414098

# %%
df
# Out:
#          a      b      c         d        e
# sr    name  study  marks      city  pincode
# 1    suraj      3     56    satara   412547
# 2   sammed      5     67      pune   423876
# 3   nilesh      6     72  banglore   454231
# 4   ritesh      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv')
df
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %%
df.head()  #head() gives fist 5 rows
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %%
df.head(1)  #if we give no in () then o/p shows given no of rows
# Out:
#    sr   name  study  marks    city  pincode
# 0   1  suraj      3     56  satara   412547

# %%
df.head(3)
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231

# %%
df.tail() #it returns data from bottom and default value is 5
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %%
df.tail(2) #returns 2 rows fron bottom
# Out:
#    sr    name  study  marks      city  pincode
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %%
df.tail(1)
# Out:
#    sr    name  study  marks    city  pincode
# 3   4  ritesh      4     63  mumbai   414098

# %%
df
# Out:
#    sr    name  study  marks      city  pincode
# 0   1   suraj      3     56    satara   412547
# 1   2  sammed      5     67      pune   423876
# 2   3  nilesh      6     72  banglore   454231
# 3   4  ritesh      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',dtype = {'sr':'float64'}) #changes data type of columns
df
# Out:
#     sr    name  study  marks      city  pincode
# 0  1.0   suraj      3     56    satara   412547
# 1  2.0  sammed      5     67      pune   423876
# 2  3.0  nilesh      6     72  banglore   454231
# 3  4.0  ritesh      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',dtype = {'sr':'float64','pincode':'float64'})
df #for multiple columns changing data type
# Out:
#     sr    name  study  marks      city   pincode
# 0  1.0   suraj      3     56    satara  412547.0
# 1  2.0  sammed      5     67      pune  423876.0
# 2  3.0  nilesh      6     72  banglore  454231.0
# 3  4.0  ritesh      4     63    mumbai  414098.0

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',true_values = ['nilesh','sammed','suraj','ritesh']) #returns true value
df
# Out:
#    sr  name  study  marks      city  pincode
# 0   1  True      3     56    satara   412547
# 1   2  True      5     67      pune   423876
# 2   3  True      6     72  banglore   454231
# 3   4  True      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',false_values = ['nilesh','sammed','suraj','ritesh'])
df
# Out:
#    sr   name  study  marks      city  pincode
# 0   1  False      3     56    satara   412547
# 1   2  False      5     67      pune   423876
# 2   3  False      6     72  banglore   454231
# 3   4  False      4     63    mumbai   414098

# %%
df = pd.read_csv('C:\\Users\\abc\\Documents\\book3.csv',true_values = ['nilesh','sammed'],false_values=['suraj','ritesh'])
df
# Out:
#    sr   name  study  marks      city  pincode
# 0   1  False      3     56    satara   412547
# 1   2   True      5     67      pune   423876
# 2   3   True      6     72  banglore   454231
# 3   4  False      4     63    mumbai   414098
