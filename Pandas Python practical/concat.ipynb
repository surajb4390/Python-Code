# %%
import pandas as pd

# %%
sr = pd.Series([0,1,2,3])
sr
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
sr2 = pd.Series([0,1,2,3])
sr2
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
pd.concat([sr,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
sr3 = pd.Series([0,1,2,3,6,9])
sr3
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    6
# 5    9
# dtype: int64

# %%
pd.concat([sr,sr3])
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 0    0
# 1    1
# 2    2
# 3    3
# 4    6
# 5    9
# dtype: int64

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'],'Class':[1,2,3,4]})
df1
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4

# %%
df2 = pd.DataFrame({'ID':[5,6,7,8],'Name':['E','F','G','H'],'Class':[5,6,7,8]})

# %%
df2
# Out:
#    ID Name  Class
# 0   5    E      5
# 1   6    F      6
# 2   7    G      7
# 3   8    H      8

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4
# 0   5    E      5
# 1   6    F      6
# 2   7    G      7
# 3   8    H      8

# %%
pd.concat([df2,df1])
# Out:
#    ID Name  Class
# 0   5    E      5
# 1   6    F      6
# 2   7    G      7
# 3   8    H      8
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      1   5    E      5
# 1   2    B      2   6    F      6
# 2   3    C      3   7    G      7
# 3   4    D      4   8    H      8

# %%
pd.concat([df1,df2],axis = 0,ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4
# 4   5    E      5
# 5   6    F      6
# 6   7    G      7
# 7   8    H      8

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'],'Class':[1,2,3,4]})
df1
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4

# %%
df2 = pd.DataFrame({'ID':[3,4],'Name':['C','D'],'Class':[3,4]})
df2
# Out:
#    ID Name  Class
# 0   3    C      3
# 1   4    D      4

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4
# 0   3    C      3
# 1   4    D      4

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      1  3.0    C    3.0
# 1   2    B      2  4.0    D    4.0
# 2   3    C      3  NaN  NaN    NaN
# 3   4    D      4  NaN  NaN    NaN

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'],'Class':[1,2,3,4]})
df1
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4

# %%
df2 = pd.DataFrame({'ID':[5,6,7,8],'Name':['E','F','G','H'],'Class':[5,6,7,8]})
df2
# Out:
#    ID Name  Class
# 0   5    E      5
# 1   6    F      6
# 2   7    G      7
# 3   8    H      8

# %%
pd.concat([df1,df2],keys=['first df','second df']) #keys give lable for dataframe
# Out:
#              ID Name  Class
# first df  0   1    A      1
#           1   2    B      2
#           2   3    C      3
#           3   4    D      4
# second df 0   5    E      5
#           1   6    F      6
#           2   7    G      7
#           3   8    H      8

# %%
pd.concat([df1,df2],axis = 1,keys=['first df','second df'])
# Out:
#   first df            second df
#         ID Name Class        ID Name Class
# 0        1    A     1         5    E     5
# 1        2    B     2         6    F     6
# 2        3    C     3         7    G     7
# 3        4    D     4         8    H     8

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'],'Class':[1,2,3,4]})
df1
# Out:
#    ID Name  Class
# 0   1    A      1
# 1   2    B      2
# 2   3    C      3
# 3   4    D      4

# %%
df2 = pd.DataFrame({'marks':[40,50,60,70]})
df2
# Out:
#    marks
# 0     40
# 1     50
# 2     60
# 3     70

# %%
pd.concat([df1,df2])
# Out:
#     ID Name  Class  marks
# 0  1.0    A    1.0    NaN
# 1  2.0    B    2.0    NaN
# 2  3.0    C    3.0    NaN
# 3  4.0    D    4.0    NaN
# 0  NaN  NaN    NaN   40.0
# 1  NaN  NaN    NaN   50.0
# 2  NaN  NaN    NaN   60.0
# 3  NaN  NaN    NaN   70.0
